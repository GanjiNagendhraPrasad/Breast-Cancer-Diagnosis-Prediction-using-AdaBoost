# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv('/content/breast-cancer.csv')
df=df.drop(['id','Unnamed: 32'],axis=1)
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1}).astype(int)
df.sample(10)
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 86           0        14.48         21.46           94.25      648.2
# 94           0        15.06         19.83          100.30      705.6
# 280          0        19.16         26.60          126.20     1138.0
# 191          1        12.77         21.41           82.02      507.4
# 360          1        12.54         18.07           79.42      491.9
# 127          0        19.00         18.91          123.40     1138.0
# 264          0        17.19         22.07          111.60      928.3
# 534          1        10.96         17.62           70.79      365.6
# 13           0        15.85         23.95          103.70      782.7
# 536          0        14.27         22.55           93.77      629.8
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 86           0.09444           0.09947        0.120400             0.049380
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=42)

# %%
len(x_train),len(y_train)
# Out:
# (455, 455)

# %%
len(x_test),len(y_test)
# Out:
# (114, 114)

# %%
from sklearn.linear_model import LogisticRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.ensemble import AdaBoostClassifier
lr=LogisticRegression()
reg=AdaBoostClassifier(estimator=lr,n_estimators=5)
reg.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(estimator=LogisticRegression(), n_estimators=5)

# %%
ans=reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
confusion_matrix(y_test,ans)
# Out:
# array([[41,  2],
#        [ 1, 70]])

# %%
print(classification_report(y_test,ans))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        43
#            1       0.97      0.99      0.98        71
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
accuracy_score(y_test,ans)
# Out:
# 0.9736842105263158

# %%
import pickle

# %%
with open('adab.pkl','wb') as f:
  pickle.dump(reg,f)
